# %% [markdown]
# # Dados de treinamento:

# %%
df = spark.table("houseprices.bronze.bronze_train")
display(df)

# %% [markdown]
# # Dados de teste:

# %%
df = spark.table("houseprices.bronze.bronze_test")
display(df)
